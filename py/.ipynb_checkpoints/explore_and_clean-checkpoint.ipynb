# %% [markdown]
# TODO:
# - Create synthetic data!!!!!!!!
# - Check for negative aggregate numbers.
# - Replicate table 3.4 from Chaoyun's paper
# - Check Chaoyun's code

# %%
from __future__ import division

from utils import *
from create_data import *

import os
import pandas as pd
import numpy as np
from collections import OrderedDict
import time
from datetime import datetime
from datetime import date
from datetime import timedelta
from dateutil.parser import parse

# import sqlite3

from ggplot import *
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# ### R stuff

# %%
# If you want to ignore R warnings.
# import warnings
# warnings.filterwarnings('ignore')

# from rpy2.robjects.packages import isinstalled
# from rpy2.robjects.vectors import StrVector
# import rpy2.robjects.packages as rpackages
# from rpy2.robjects.packages import importr

# utils = rpackages.importr('utils')
# utils.chooseCRANmirror(ind=1) # select the first mirror in the list

# packnames = ('forecast')
# utils.install_packages(packnames)

# isinstalled('forecast')

# %%R
# y <- 1

# %load_ext rpy2.ipython

# %% [markdown]
# ### Define project vars

# %%
dir_proj = '/Users/sipola/Google Drive/education/coursework/graduate/edinburgh/dissertation/thesis'
dir_data = os.path.join(dir_proj, 'data')
dir_run = os.path.join(dir_proj, 'run', str(date.today()))

# %%
HOUSE_IDS = range(1, 22); HOUSE_IDS.remove(14)  # no house 14
app_names = ['fridge', 'kettle', 'washing machine', 'dishwasher', 'microwave']
# tz = 'Europe/London'

# %%
# params_appliance = get_params_appliance()
dir_refit_csv = os.path.join(dir_data, 'CLEAN_REFIT_081116')
dir_refit = os.path.join(dir_data, 'refit')

# %%
save_refit_data(dir_refit_csv=dir_refit_csv,
                dir_refit_np=dir_refit,
                nrows=None)
# Out:
# writing REFIT data...
# added house 1 (0.31 min)
# added house 2 (0.25 min)
# added house 3 (0.32 min)
# added house 4 (0.37 min)
# added house 5 (0.37 min)
# added house 6 (0.31 min)
# added house 7 (0.32 min)
# added house 8 (0.33 min)
# added house 9 (0.24 min)
# added house 10 (0.34 min)
# added house 11 (0.32 min)
# added house 12 (0.29 min)
# added house 13 (0.26 min)
# added house 15 (0.36 min)
# added house 16 (0.27 min)
# added house 17 (0.25 min)
# added house 18 (0.24 min)
# added house 19 (0.22 min)
# added house 20 (0.19 min)
# added house 21 (0.2 min)
# done!

# %%
apps = pd.read_csv(os.path.join(dir_data, 'appliances.csv'))
app_dict = create_app_dict()
apps = apps_add_cols_from_patterns(app_dict)

# %%
get_house_app_tuples, get_app_nums, get_app_name = create_app_funs(apps, app_dict)
load_app, load_ts, load_issues = create_load_funs(dir_refit)

# app_col, pattern = app_col_and_pattern_tuples[1]
# for i in apps.loc[apps[app_col] == 1]['ApplianceOrig'].values:
#     print i

# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('fridge')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('kettle')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('washi')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('dish')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('micro')]

# get_house_app_tuples('fridge')
# get_house_app_tuples('kettle')
# get_house_app_tuples('washing machine')

# %%
# Note change in fridge-freezer model.
# plot_app_change(4, datetime(2014,8,17), app_names='fridge-freezer')

# %%
# Note how it appears to be a kettle and not a computer site.
# plot_app_change(12, datetime(2014,5,17), day_range=np.array(range(-5,5))*7, app_names='kettle')

# %%
create_daily_plots(house_ids, dir_run)

# %%
dstats = create_daily_stats(house_ids,
                            pkl_path=os.path.join(dir_data, 'stats_by_day.pkl'),
                            nrow=None)
# Out:
# calculating stats for house 1...
# calculating stats for house 2...
# calculating stats for house 3...
# calculating stats for house 4...
# calculating stats for house 5...
# calculating stats for house 6...
# calculating stats for house 7...
# calculating stats for house 8...
# calculating stats for house 9...
# calculating stats for house 10...
# calculating stats for house 11...
# calculating stats for house 12...
# calculating stats for house 13...
# calculating stats for house 15...
# calculating stats for house 16...
# calculating stats for house 17...
# calculating stats for house 18...
# calculating stats for house 19...
# calculating stats for house 20...
# calculating stats for house 21...
# done!

# %%
dstats.head()
# Out:
#            RowNum                Time                      UnixDiff  \
#               len                 min                 max       max
# Time
# 2013-10-09   5164 2013-10-09 13:06:17 2013-10-09 23:59:59  1.211944
# 2013-10-10  12878 2013-10-10 00:00:00 2013-10-10 23:59:46  0.212222
# 2013-10-11  13651 2013-10-11 00:00:00 2013-10-11 23:59:46  0.014167
# 2013-10-12  13890 2013-10-12 00:00:00 2013-10-12 23:59:58  0.220278
# 2013-10-13  14302 2013-10-13 00:00:01 2013-10-13 23:59:59  0.004722
#
#            EnergySumOfParts PctAccountedEnergy Issues            \
#                         sum                std    sum      mean
# Time
# 2013-10-09         0.638810           0.264682    6.0  0.001162
# 2013-10-10         2.677231           0.719849    6.0  0.000466
# 2013-10-11         1.358534           0.239261    6.0  0.000440
# 2013-10-12         1.303619           0.248237    6.0  0.000432
# 2013-10-13         1.272069           0.210869    6.0  0.000420
#
#            EnergyAppliance0 EnergyAppliance1  ...  EnergyAppliance4  \
#                         sum              sum  ...               sum
# Time                                          ...
# 2013-10-09         5.156559         0.132198  ...          0.004568
# 2013-10-10        13.737292         0.415929  ...          0.000329
# 2013-10-11         5.657950         0.319277  ...          0.000000
# 2013-10-12         5.147623         0.318191  ...          0.000000
# 2013-10-13         5.143264         0.276128  ...          0.000000
#
#            EnergyAppliance5 EnergyAppliance6 EnergyAppliance7  \
#                         sum              sum              sum
# Time
# 2013-10-09              0.0         0.000000         0.000000
# 2013-10-10              0.0         0.882526         0.028912
# 2013-10-11              0.0         0.000000         0.000000
# 2013-10-12              0.0         0.000000         0.000000
# 2013-10-13              0.0         0.000000         0.000000
#
#            EnergyAppliance8 EnergyAppliance9 SumToMainCorr PctAccountedEnergy  \
#                         sum              sum                            total
# Time
# 2013-10-09         0.075760         0.010896      0.370633           0.123883
# 2013-10-10         0.163212         0.023990      0.255051           0.194888
# 2013-10-11         0.001484         0.023997      0.396753           0.240111
# 2013-10-12         0.001527         0.023970      0.831595           0.253247
# 2013-10-13         0.001493         0.023989      0.549391           0.247327
#
#             HourRange House
#
# Time
# 2013-10-09  10.895000     1
# 2013-10-10  23.996111     1
# 2013-10-11  23.996111     1
# 2013-10-12  23.999444     1
# 2013-10-13  23.999444     1
#
# [5 rows x 22 columns]

# %%
dstats = pd.read_pickle(os.path.join(dir_data, 'stats_by_day.pkl'))

# %%
dstats.loc[dstats['House']==2]
# Out:
#            RowNum                Time                      UnixDiff  \
#               len                 min                 max       max
# Time
# 2013-09-17   1112 2013-09-17 22:08:11 2013-09-17 23:59:59  0.010000
# 2013-09-18  13366 2013-09-18 00:00:07 2013-09-18 23:59:53  0.503056
# 2013-09-19  14042 2013-09-19 00:00:00 2013-09-19 23:59:59  0.271389
# 2013-09-20  14273 2013-09-20 00:00:07 2013-09-20 23:59:52  0.006944
# 2013-09-21  14158 2013-09-21 00:00:00 2013-09-21 23:59:53  0.003611
# 2013-09-22  14367 2013-09-22 00:00:00 2013-09-22 23:59:59  0.017500
# 2013-09-23  14252 2013-09-23 00:00:06 2013-09-23 23:59:59  0.004444
# 2013-09-24  14245 2013-09-24 00:00:06 2013-09-24 23:59:58  0.007222
# 2013-09-25  14160 2013-09-25 00:00:06 2013-09-25 23:59:55  0.242500
# 2013-09-26  13669 2013-09-26 00:00:02 2013-09-26 23:59:53  0.307778
# 2013-09-27  12580 2013-09-27 00:00:00 2013-09-27 23:59:53  0.506111
# 2013-09-28  13958 2013-09-28 00:00:00 2013-09-28 23:59:59  0.299444
# 2013-09-29  14092 2013-09-29 00:00:06 2013-09-29 23:59:53  0.137778
# 2013-09-30  14196 2013-09-30 00:00:00 2013-09-30 23:59:52  0.273611
# 2013-10-01  14319 2013-10-01 00:00:00 2013-10-01 23:59:53  0.009444
# 2013-10-02  14006 2013-10-02 00:00:00 2013-10-02 23:59:46  0.096111
# 2013-10-03  12660 2013-10-03 00:00:00 2013-10-03 23:59:46  0.237222
# 2013-10-04  12521 2013-10-04 00:00:00 2013-10-04 23:59:47  0.007222
# 2013-10-05  12621 2013-10-05 00:00:01 2013-10-05 23:59:46  0.214722
# 2013-10-06  12983 2013-10-06 00:00:00 2013-10-06 23:59:46  0.235556
# 2013-10-07  12743 2013-10-07 00:00:00 2013-10-07 23:59:47  0.215000
# 2013-10-08  12332 2013-10-08 00:00:00 2013-10-08 23:59:46  0.213056
# 2013-10-09  12408 2013-10-09 00:00:00 2013-10-09 23:59:47  0.212500
# 2013-10-10  11684 2013-10-10 00:00:01 2013-10-10 23:59:47  0.007500
# 2013-10-11  12274 2013-10-11 00:00:01 2013-10-11 23:59:47  0.226389
# 2013-10-12  12563 2013-10-12 00:00:01 2013-10-12 23:59:47  0.221667
# 2013-10-13  12384 2013-10-13 00:00:01 2013-10-13 23:59:48  0.277500
# 2013-10-14  12154 2013-10-14 00:00:01 2013-10-14 23:59:48  0.029444
# 2013-10-15  11919 2013-10-15 00:00:01 2013-10-15 23:59:48  0.008611
# 2013-10-16  12018 2013-10-16 00:00:01 2013-10-16 23:59:47  0.008889
# ...           ...                 ...                 ...       ...
# 2015-04-29  12437 2015-04-29 00:00:03 2015-04-29 23:59:57  0.634722
# 2015-04-30  12909 2015-04-30 00:00:04 2015-04-30 23:59:56  0.019722
# 2015-05-01  12920 2015-05-01 00:00:03 2015-05-01 23:59:55  0.006389
# 2015-05-02  12915 2015-05-02 00:00:02 2015-05-02 23:59:57  0.013333
# 2015-05-03  12942 2015-05-03 00:00:04 2015-05-03 23:59:56  0.002500
# 2015-05-04  12927 2015-05-04 00:00:03 2015-05-04 23:59:57  0.015000
# 2015-05-05  12937 2015-05-05 00:00:03 2015-05-05 23:59:54  0.003056
# 2015-05-06  12920 2015-05-06 00:00:00 2015-05-06 23:59:53  0.014444
# 2015-05-07  12963 2015-05-07 00:00:00 2015-05-07 23:59:54  0.002222
# 2015-05-08  12934 2015-05-08 00:00:01 2015-05-08 23:59:55  0.013056
# 2015-05-09  12942 2015-05-09 00:00:02 2015-05-09 23:59:53  0.003056
# 2015-05-10  11946 2015-05-10 00:00:00 2015-05-10 23:36:09  1.455833
# 2015-05-11      0                 NaT                 NaT       NaN
# 2015-05-12      0                 NaT                 NaT       NaN
# 2015-05-13      0                 NaT                 NaT       NaN
# 2015-05-14      0                 NaT                 NaT       NaN
# 2015-05-15      0                 NaT                 NaT       NaN
# 2015-05-16      0                 NaT                 NaT       NaN
# 2015-05-17      0                 NaT                 NaT       NaN
# 2015-05-18      0                 NaT                 NaT       NaN
# 2015-05-19   4887 2015-05-19 15:10:24 2015-05-19 23:59:59  0.002500
# 2015-05-20  12911 2015-05-20 00:00:05 2015-05-20 23:59:53  0.025000
# 2015-05-21  10777 2015-05-21 00:00:00 2015-05-21 23:59:56  3.541389
# 2015-05-22  12741 2015-05-22 00:00:03 2015-05-22 23:59:55  0.009444
# 2015-05-23  12957 2015-05-23 00:00:02 2015-05-23 23:59:56  0.003333
# 2015-05-24  12955 2015-05-24 00:00:03 2015-05-24 23:59:57  0.020833
# 2015-05-25  12938 2015-05-25 00:00:04 2015-05-25 23:59:56  0.019722
# 2015-05-26  12942 2015-05-26 00:00:03 2015-05-26 23:59:58  0.018889
# 2015-05-27  12936 2015-05-27 00:00:04 2015-05-27 23:59:57  0.003056
# 2015-05-28   4382 2015-05-28 00:00:04 2015-05-28 08:05:43  0.008889
#
#            EnergySumOfParts PctAccountedEnergy Issues            \
#                         sum                std    sum      mean
# Time
# 2013-09-17         0.063511           0.235400    6.0  0.005396
# 2013-09-18         2.602131           0.586756    6.0  0.000449
# 2013-09-19         3.211457           0.462957    6.0  0.000427
# 2013-09-20         4.567941           0.587591    6.0  0.000420
# 2013-09-21         2.891039           0.423353    6.0  0.000424
# 2013-09-22         4.018201           0.427872    6.0  0.000418
# 2013-09-23         4.343104           0.364792    6.0  0.000421
# 2013-09-24         1.566694           0.569630    6.0  0.000421
# 2013-09-25         5.153094                NaN    6.0  0.000424
# 2013-09-26         2.659434           0.536822    6.0  0.000439
# 2013-09-27         2.521463           0.383898    6.0  0.000477
# 2013-09-28         3.269198           1.273599    6.0  0.000430
# 2013-09-29         5.630998           2.115472    6.0  0.000426
# 2013-09-30         3.732133                NaN    6.0  0.000423
# 2013-10-01         3.078343           0.480317    6.0  0.000419
# 2013-10-02         3.817797                NaN    6.0  0.000428
# 2013-10-03         3.039721           0.551866    6.0  0.000474
# 2013-10-04         2.013538           0.847933    6.0  0.000479
# 2013-10-05         3.496043           0.592487    6.0  0.000475
# 2013-10-06         4.311906           0.401484    6.0  0.000462
# 2013-10-07         4.367158           0.582080    6.0  0.000471
# 2013-10-08         2.963715           0.562998    6.0  0.000487
# 2013-10-09         4.805124           0.884342    6.0  0.000484
# 2013-10-10         3.202493           0.535764    6.0  0.000514
# 2013-10-11         4.301357           0.629385    6.0  0.000489
# 2013-10-12         3.245126           0.398202    6.0  0.000478
# 2013-10-13         3.750143           0.471405    6.0  0.000484
# 2013-10-14         3.516608           0.423816    6.0  0.000494
# 2013-10-15         3.626596           1.250718    6.0  0.000503
# 2013-10-16         2.351474           0.416802    6.0  0.000499
# ...                     ...                ...    ...       ...
# 2015-04-29         5.335280                NaN    6.0  0.000482
# 2015-04-30         3.959996           0.342831    6.0  0.000465
# 2015-05-01         4.640401           0.443400    6.0  0.000464
# 2015-05-02         6.646836           0.349059    6.0  0.000465
# 2015-05-03         8.458230           0.364142    6.0  0.000464
# 2015-05-04         1.154063           0.357496    6.0  0.000464
# 2015-05-05         0.709398           0.265605    6.0  0.000464
# 2015-05-06         0.596892           0.333449    6.0  0.000464
# 2015-05-07         0.610728           0.253837    6.0  0.000463
# 2015-05-08         2.346878           0.281800    6.0  0.000464
# 2015-05-09         4.966603           0.365414    6.0  0.000464
# 2015-05-10         1.312987           0.305653    6.0  0.000502
# 2015-05-11              NaN                NaN    NaN       NaN
# 2015-05-12              NaN                NaN    NaN       NaN
# 2015-05-13              NaN                NaN    NaN       NaN
# 2015-05-14              NaN                NaN    NaN       NaN
# 2015-05-15              NaN                NaN    NaN       NaN
# 2015-05-16              NaN                NaN    NaN       NaN
# 2015-05-17              NaN                NaN    NaN       NaN
# 2015-05-18              NaN                NaN    NaN       NaN
# 2015-05-19         1.148342           0.517648    6.0  0.001228
# 2015-05-20         5.351422           0.365797    6.0  0.000465
# 2015-05-21         2.436417           0.299337    6.0  0.000557
# 2015-05-22         6.918607           0.513932    6.0  0.000471
# 2015-05-23         1.261898           0.215218    6.0  0.000463
# 2015-05-24         0.802378           0.212561    6.0  0.000463
# 2015-05-25         0.706116           0.179088    6.0  0.000464
# 2015-05-26         0.661292           0.136549    6.0  0.000464
# 2015-05-27         1.027673           0.178149    6.0  0.000464
# 2015-05-28         1.690423           0.310992    6.0  0.001369
#
#            EnergyAppliance0 EnergyAppliance1  ...  EnergyAppliance4  \
#                         sum              sum  ...               sum
# Time                                          ...
# 2013-09-17         0.337296         0.063511  ...          0.000000
# 2013-09-18        10.120525         0.743208  ...          0.045954
# 2013-09-19         7.479372         0.866517  ...          0.158949
# 2013-09-20         9.116565         0.869979  ...          0.332560
# 2013-09-21         6.899041         0.713046  ...          0.228990
# 2013-09-22         7.633240         0.916392  ...          0.123613
# 2013-09-23         8.881662         0.875298  ...          0.124963
# 2013-09-24         6.908410         0.874423  ...          0.152764
# 2013-09-25        10.514969         0.918354  ...          0.063878
# 2013-09-26         6.965303         0.899578  ...          0.169294
# 2013-09-27         6.451494         0.831313  ...          0.161024
# 2013-09-28        12.066736         0.873189  ...          0.214669
# 2013-09-29        14.514441         0.897189  ...          0.098529
# 2013-09-30         8.392597         1.069294  ...          0.173688
# 2013-10-01         6.159543         0.810623  ...          0.118467
# 2013-10-02         8.634627         0.757853  ...          0.122598
# 2013-10-03         7.337384         0.950337  ...          0.176089
# 2013-10-04         5.911639         0.822867  ...          0.160466
# 2013-10-05         9.656419         0.885390  ...          0.185577
# 2013-10-06        13.580889         0.954703  ...          0.053917
# 2013-10-07         9.742256         1.011697  ...          0.193420
# 2013-10-08         8.626801         0.861763  ...          0.136619
# 2013-10-09         8.970898         0.822631  ...          0.061568
# 2013-10-10         7.902527         0.841220  ...          0.217661
# 2013-10-11        10.448100         0.886197  ...          0.264683
# 2013-10-12        12.177435         0.937893  ...          0.151484
# 2013-10-13        10.753729         0.824915  ...          0.139302
# 2013-10-14         8.243315         0.878115  ...          0.306639
# 2013-10-15         8.076613         0.782053  ...          0.104258
# 2013-10-16         5.882918         0.688272  ...          0.061750
# ...                     ...              ...  ...               ...
# 2015-04-29        12.660586         0.782400  ...          0.135278
# 2015-04-30        10.793139         0.870516  ...          0.158534
# 2015-05-01        11.753065         1.047918  ...          0.041962
# 2015-05-02        16.814836         1.201008  ...          0.254249
# 2015-05-03        24.461428         1.118532  ...          0.099126
# 2015-05-04         6.009967         0.811558  ...          0.054056
# 2015-05-05         2.563504         0.709398  ...          0.000000
# 2015-05-06         2.458196         0.596892  ...          0.000000
# 2015-05-07         2.477673         0.610713  ...          0.000000
# 2015-05-08        12.173504         0.658940  ...          0.000000
# 2015-05-09        30.817189         0.902715  ...          0.191412
# 2015-05-10         5.960884         0.856744  ...          0.037988
# 2015-05-11              NaN              NaN  ...               NaN
# 2015-05-12              NaN              NaN  ...               NaN
# 2015-05-13              NaN              NaN  ...               NaN
# 2015-05-14              NaN              NaN  ...               NaN
# 2015-05-15              NaN              NaN  ...               NaN
# 2015-05-16              NaN              NaN  ...               NaN
# 2015-05-17              NaN              NaN  ...               NaN
# 2015-05-18              NaN              NaN  ...               NaN
# 2015-05-19         3.948587         0.308502  ...          0.040263
# 2015-05-20        12.678667         0.778743  ...          0.196437
# 2015-05-21        15.069123         0.964744  ...          0.000000
# 2015-05-22        25.526212         1.175459  ...          0.060269
# 2015-05-23        14.255091         1.024179  ...          0.000000
# 2015-05-24        10.327824         0.796605  ...          0.000000
# 2015-05-25        11.037918         0.703438  ...          0.000000
# 2015-05-26        22.452913         0.661117  ...          0.000000
# 2015-05-27        21.262234         0.742353  ...          0.000000
# 2015-05-28         4.241072         0.309718  ...          0.016049
#
#            EnergyAppliance5 EnergyAppliance6 EnergyAppliance7  \
#                         sum              sum              sum
# Time
# 2013-09-17         0.000000         0.000000         0.000000
# 2013-09-18         0.059302         0.085371         0.000000
# 2013-09-19         0.095688         0.088272         0.008484
# 2013-09-20         0.062687         0.073491         0.000343
# 2013-09-21         0.020390         0.078426         0.006828
# 2013-09-22         0.068324         0.046098         0.000000
# 2013-09-23         0.040123         0.033507         0.000000
# 2013-09-24         0.110576         0.000000         0.000000
# 2013-09-25         0.059460         0.000000         0.000172
# 2013-09-26         0.191799         0.000000         0.000000
# 2013-09-27         0.017443         0.114291         0.000000
# 2013-09-28         0.143923         0.047584         0.000000
# 2013-09-29         0.238234         0.000000         0.067472
# 2013-09-30         0.056455         0.000180         0.221942
# 2013-10-01         0.109243         0.002652         0.114177
# 2013-10-02         0.097576         0.000000         0.000000
# 2013-10-03         0.034761         0.000000         0.015512
# 2013-10-04         0.109168         0.005223         0.016046
# 2013-10-05         0.079513         0.000309         0.247587
# 2013-10-06         0.064205         0.000000         0.033524
# 2013-10-07         0.184418         0.023955         0.166755
# 2013-10-08         0.081456         0.057979         0.281841
# 2013-10-09         0.273062         0.043746         0.096380
# 2013-10-10         0.119935         0.000000         0.005687
# 2013-10-11         0.110329         0.000000         0.002560
# 2013-10-12         0.078816         0.062735         0.019599
# 2013-10-13         0.082738         0.044096         0.046541
# 2013-10-14         0.090879         0.050440         0.000000
# 2013-10-15         0.216734         0.031650         0.000133
# 2013-10-16         0.030708         0.108553         0.028081
# ...                     ...              ...              ...
# 2015-04-29         0.099291         0.000000         0.005473
# 2015-04-30         0.117282         0.028686         0.020389
# 2015-05-01         0.056598         0.000000         0.001991
# 2015-05-02         0.112902         0.083812         0.041614
# 2015-05-03         0.161836         0.063004         0.214419
# 2015-05-04         0.029603         0.031294         0.000000
# 2015-05-05         0.000000         0.000000         0.000000
# 2015-05-06         0.000000         0.000000         0.000000
# 2015-05-07         0.000000         0.000000         0.000000
# 2015-05-08         0.014026         0.000000         0.000000
# 2015-05-09         0.058465         0.035565         0.014506
# 2015-05-10         0.084273         0.034832         0.000000
# 2015-05-11              NaN              NaN              NaN
# 2015-05-12              NaN              NaN              NaN
# 2015-05-13              NaN              NaN              NaN
# 2015-05-14              NaN              NaN              NaN
# 2015-05-15              NaN              NaN              NaN
# 2015-05-16              NaN              NaN              NaN
# 2015-05-17              NaN              NaN              NaN
# 2015-05-18              NaN              NaN              NaN
# 2015-05-19         0.367994         0.000089         0.000000
# 2015-05-20         0.059126         0.026738         0.006076
# 2015-05-21         0.083361         0.006187         0.000000
# 2015-05-22         0.125338         0.000489         0.000000
# 2015-05-23         0.025878         0.000000         0.000082
# 2015-05-24         0.000000         0.000000         0.000000
# 2015-05-25         0.000000         0.002094         0.000000
# 2015-05-26         0.000000         0.000163         0.000000
# 2015-05-27         0.010823         0.054266         0.000000
# 2015-05-28         0.046847         0.043536         0.000000
#
#            EnergyAppliance8 EnergyAppliance9 SumToMainCorr PctAccountedEnergy  \
#                         sum              sum                            total
# Time
# 2013-09-17         0.000000         0.000000      0.689744           0.188295
# 2013-09-18         0.596790         0.000000      0.131090           0.257114
# 2013-09-19         0.455708         0.000000      0.456679           0.429375
# 2013-09-20         0.576106         0.024019      0.539293           0.501059
# 2013-09-21         0.383903         0.000000      0.447064           0.419049
# 2013-09-22         0.697028         0.090824      0.694556           0.526408
# 2013-09-23         0.530954         0.000000      0.633838           0.488997
# 2013-09-24         0.428316         0.000000      0.259325           0.226781
# 2013-09-25         0.785441         0.036716      0.448397           0.490072
# 2013-09-26         0.366479         0.000000      0.537346           0.381812
# 2013-09-27         0.239437         0.000000      0.666918           0.390834
# 2013-09-28         0.854352         0.002171      0.448037           0.270926
# 2013-09-29         0.552835         0.000000      0.472859           0.387958
# 2013-09-30         0.791844         0.007862      0.519900           0.444693
# 2013-10-01         0.615740         0.000000      0.768732           0.499768
# 2013-10-02         0.515060         0.000000      0.607654           0.442150
# 2013-10-03         0.507434         0.009912      0.495133           0.414279
# 2013-10-04         0.286394         0.020333      0.378405           0.340606
# 2013-10-05         0.818320         0.000133      0.942167           0.362043
# 2013-10-06         0.477619         0.096776      0.431661           0.317498
# 2013-10-07         0.443879         0.000000      0.947957           0.448270
# 2013-10-08         0.370848         0.000008      0.414519           0.343547
# 2013-10-09         0.485036         0.000000      0.926823           0.535635
# 2013-10-10         0.574203         0.013824      0.458991           0.405249
# 2013-10-11         0.614231         0.027383      0.501613           0.411688
# 2013-10-12         0.815411         0.008122      0.467258           0.266487
# 2013-10-13         0.586445         0.000000      0.559777           0.348730
# 2013-10-14         0.672133         0.020093      0.779343           0.426601
# 2013-10-15         0.476222         0.000000      0.720701           0.449024
# 2013-10-16         0.266689         0.000000      0.890697           0.399712
# ...                     ...              ...           ...                ...
# 2015-04-29         0.673482         0.000000      0.316032           0.421409
# 2015-04-30         0.534804         0.037069      0.389987           0.366899
# 2015-05-01         0.586097         0.021190      0.503285           0.394825
# 2015-05-02         0.652343         0.000000      0.709502           0.395296
# 2015-05-03         1.188475         0.003788      0.498544           0.345778
# 2015-05-04         0.227551         0.000000      0.152449           0.192025
# 2015-05-05         0.000000         0.000000      0.944127           0.276730
# 2015-05-06         0.000000         0.000000      0.842714           0.242817
# 2015-05-07         0.000000         0.000000      0.921133           0.246493
# 2015-05-08         0.183468         0.000000      0.741457           0.192786
# 2015-05-09         0.818619         0.015969      0.384427           0.161163
# 2015-05-10         0.298156         0.000000      0.243129           0.220267
# 2015-05-11              NaN              NaN           NaN                NaN
# 2015-05-12              NaN              NaN           NaN                NaN
# 2015-05-13              NaN              NaN           NaN                NaN
# 2015-05-14              NaN              NaN           NaN                NaN
# 2015-05-15              NaN              NaN           NaN                NaN
# 2015-05-16              NaN              NaN           NaN                NaN
# 2015-05-17              NaN              NaN           NaN                NaN
# 2015-05-18              NaN              NaN           NaN                NaN
# 2015-05-19         0.431496         0.000000      0.720295           0.290824
# 2015-05-20         0.718324         0.027121      0.662802           0.422081
# 2015-05-21         0.889614         0.000000      0.968559           0.161683
# 2015-05-22         0.886099         0.000000      0.411127           0.271039
# 2015-05-23         0.211759         0.000000      0.114665           0.088523
# 2015-05-24         0.005689         0.000000      0.082367           0.077691
# 2015-05-25         0.000084         0.000000     -0.006448           0.063972
# 2015-05-26         0.000000         0.000000      0.011260           0.029452
# 2015-05-27         0.201149         0.000000      0.124069           0.048333
# 2015-05-28         0.112952         0.000000      0.388743           0.398584
#
#             HourRange House
#
# Time
# 2013-09-17   1.863333     2
# 2013-09-18  23.996111     2
# 2013-09-19  23.999722     2
# 2013-09-20  23.995833     2
# 2013-09-21  23.998056     2
# 2013-09-22  23.999722     2
# 2013-09-23  23.998056     2
# 2013-09-24  23.997778     2
# 2013-09-25  23.996944     2
# 2013-09-26  23.997500     2
# 2013-09-27  23.998056     2
# 2013-09-28  23.999722     2
# 2013-09-29  23.996389     2
# 2013-09-30  23.997778     2
# 2013-10-01  23.998056     2
# 2013-10-02  23.996111     2
# 2013-10-03  23.996111     2
# 2013-10-04  23.996389     2
# 2013-10-05  23.995833     2
# 2013-10-06  23.996111     2
# 2013-10-07  23.996389     2
# 2013-10-08  23.996111     2
# 2013-10-09  23.996389     2
# 2013-10-10  23.996111     2
# 2013-10-11  23.996111     2
# 2013-10-12  23.996111     2
# 2013-10-13  23.996389     2
# 2013-10-14  23.996389     2
# 2013-10-15  23.996389     2
# 2013-10-16  23.996111     2
# ...               ...   ...
# 2015-04-29  23.998333     2
# 2015-04-30  23.997778     2
# 2015-05-01  23.997778     2
# 2015-05-02  23.998611     2
# 2015-05-03  23.997778     2
# 2015-05-04  23.998333     2
# 2015-05-05  23.997500     2
# 2015-05-06  23.998056     2
# 2015-05-07  23.998333     2
# 2015-05-08  23.998333     2
# 2015-05-09  23.997500     2
# 2015-05-10  23.602500     2
# 2015-05-11        NaN     2
# 2015-05-12        NaN     2
# 2015-05-13        NaN     2
# 2015-05-14        NaN     2
# 2015-05-15        NaN     2
# 2015-05-16        NaN     2
# 2015-05-17        NaN     2
# 2015-05-18        NaN     2
# 2015-05-19   8.826389     2
# 2015-05-20  23.996667     2
# 2015-05-21  23.998889     2
# 2015-05-22  23.997778     2
# 2015-05-23  23.998333     2
# 2015-05-24  23.998333     2
# 2015-05-25  23.997778     2
# 2015-05-26  23.998611     2
# 2015-05-27  23.998056     2
# 2015-05-28   8.094167     2
#
# [619 rows x 22 columns]

# %%
# plot_day(2, datetime.datetime(2014,9,7), figsize=(11,8))

# %%
vars_to_plot = [{'col': ('UnixDiff', 'max'), 'ylab': 'Hours', 'title': 'Max difference in timestamps'},
                {'col': 'HourRange', 'ylab': 'Hours', 'title': 'Timestamp range'},
                {'col': ('RowNum', 'len'), 'ylab': 'Count', 'title': 'Number of observations'},
                {'col': ('PctAccountedEnergy', 'total'), 'ylab': 'Proportion of energy', 'title': 'Proportion of energy accounted for by IAMs'},
                {'col': ('PctAccountedEnergy', 'std'), 'ylab': 'Proportion of energy', 'title': 'Proportion of energy accounted for\nby IAMs (standard dev.)'},
                {'col': 'SumToMainCorr', 'ylab': 'Correlation', 'title': 'Correlation between sum of IAM\n power and aggregate power'},
                {'col': ('Issues', 'mean'), 'ylab': 'Proportion', 'title': 'Proportion of observations\nwhere sum of IAM power > aggregate power'}]
for var_to_plot in vars_to_plot:
    plot_data = pd.DataFrame({'X': sorted(dstats[var_to_plot['col']].dropna())})
    plot_data['Proportion'] = [i/plot_data.shape[0] for i in range(plot_data.shape[0])]
    ax = plot_data.set_index('Proportion').plot()
    ax.set_title(var_to_plot['title'])
    ax.set_ylabel(var_to_plot['ylab'])
    ax.legend().set_visible(False)

# %%
for var_to_plot in vars_to_plot:
    var_name = var_to_plot['col']
    kde_data = dstats[var_to_plot['col']].replace([np.inf, -np.inf], np.nan).dropna().values
    ax = sns.distplot(kde_data, rug=False)
    ax.set_title(var_to_plot['title'])
    ax.set_xlabel(var_to_plot['ylab'])
    plt.show()

# %%
# Get NaN proportions.
for var_to_plot in vars_to_plot:
    x = dstats[var_to_plot['col']].replace([np.inf, -np.inf], np.nan).values
    print '{0}: {1:0.2g}'.format(var_to_plot['col'], np.mean(np.isnan(x)))
# Out:
# ('UnixDiff', 'max'): 0.083
# HourRange: 0.083
# ('RowNum', 'len'): 0
# ('PctAccountedEnergy', 'total'): 0.084
# ('PctAccountedEnergy', 'std'): 0.12
# SumToMainCorr: 0.084
# ('Issues', 'mean'): 0.083

# %%
dstats
# Out:
#            RowNum                Time                      UnixDiff  \
#               len                 min                 max       max
# Time
# 2013-10-09   5164 2013-10-09 13:06:17 2013-10-09 23:59:59  1.211944
# 2013-10-10  12878 2013-10-10 00:00:00 2013-10-10 23:59:46  0.212222
# 2013-10-11  13651 2013-10-11 00:00:00 2013-10-11 23:59:46  0.014167
# 2013-10-12  13890 2013-10-12 00:00:00 2013-10-12 23:59:58  0.220278
# 2013-10-13  14302 2013-10-13 00:00:01 2013-10-13 23:59:59  0.004722
# 2013-10-14  14177 2013-10-14 00:00:02 2013-10-14 23:59:58  0.180278
# 2013-10-15  14072 2013-10-15 00:00:01 2013-10-15 23:59:59  0.228333
# 2013-10-16  13972 2013-10-16 00:00:01 2013-10-16 23:59:59  0.209722
# 2013-10-17  14159 2013-10-17 00:00:00 2013-10-17 23:59:46  0.231667
# 2013-10-18  14029 2013-10-18 00:00:00 2013-10-18 23:59:59  0.216389
# 2013-10-19  14201 2013-10-19 00:00:01 2013-10-19 23:59:59  0.206111
# 2013-10-20  14188 2013-10-20 00:00:01 2013-10-20 23:59:59  0.005833
# 2013-10-21  13705 2013-10-21 00:00:01 2013-10-21 23:59:58  0.285000
# 2013-10-22  14075 2013-10-22 00:00:01 2013-10-22 23:59:59  0.222222
# 2013-10-23  13731 2013-10-23 00:00:01 2013-10-23 23:59:59  0.216944
# 2013-10-24  13854 2013-10-24 00:00:00 2013-10-24 23:59:58  0.215556
# 2013-10-25  14023 2013-10-25 00:00:01 2013-10-25 23:59:59  0.213056
# 2013-10-26  13741 2013-10-26 00:00:01 2013-10-26 22:59:58  0.006111
# 2013-10-27  14540 2013-10-27 00:00:01 2013-10-27 23:59:59  0.207778
# 2013-10-28  13771 2013-10-28 00:00:01 2013-10-28 23:59:59  0.285833
# 2013-10-29  13931 2013-10-29 00:00:01 2013-10-29 23:59:59  0.221667
# 2013-10-30  13599 2013-10-30 00:00:02 2013-10-30 23:59:59  0.225278
# 2013-10-31  13723 2013-10-31 00:00:01 2013-10-31 23:59:59  0.228611
# 2013-11-01  14078 2013-11-01 00:00:02 2013-11-01 23:59:59  0.228611
# 2013-11-02  14241 2013-11-02 00:00:01 2013-11-02 23:59:58  0.112778
# 2013-11-03  14008 2013-11-03 00:00:01 2013-11-03 23:59:59  0.008889
# 2013-11-04  14046 2013-11-04 00:00:01 2013-11-04 23:59:59  0.082222
# 2013-11-05  13325 2013-11-05 00:00:01 2013-11-05 23:59:59  0.217500
# 2013-11-06  10574 2013-11-06 00:00:01 2013-11-06 23:59:49  0.215278
# 2013-11-07   3972 2013-11-07 00:00:04 2013-11-07 10:03:19  0.007222
# ...           ...                 ...                 ...       ...
# 2015-06-11      0                 NaT                 NaT       NaN
# 2015-06-12      0                 NaT                 NaT       NaN
# 2015-06-13      0                 NaT                 NaT       NaN
# 2015-06-14      0                 NaT                 NaT       NaN
# 2015-06-15      0                 NaT                 NaT       NaN
# 2015-06-16      0                 NaT                 NaT       NaN
# 2015-06-17      0                 NaT                 NaT       NaN
# 2015-06-18  11986 2015-06-18 01:39:44 2015-06-18 23:59:58  0.003333
# 2015-06-19  12897 2015-06-19 00:00:05 2015-06-19 23:59:55  0.002500
# 2015-06-20  12856 2015-06-20 00:00:02 2015-06-20 23:59:57  0.041944
# 2015-06-21  12820 2015-06-21 00:00:04 2015-06-21 23:59:59  0.002222
# 2015-06-22  12874 2015-06-22 00:00:06 2015-06-22 23:59:58  0.079167
# 2015-06-23   4673 2015-06-23 00:00:05 2015-06-23 08:50:14  0.036389
# 2015-06-24   6188 2015-06-24 12:23:39 2015-06-24 23:59:59  0.067222
# 2015-06-25  12864 2015-06-25 00:00:05 2015-06-25 23:59:59  0.003056
# 2015-06-26  12876 2015-06-26 00:00:06 2015-06-26 23:59:53  0.002222
# 2015-06-27  12882 2015-06-27 00:00:00 2015-06-27 23:59:56  0.009167
# 2015-06-28  12682 2015-06-28 00:00:03 2015-06-28 23:59:55  0.203889
# 2015-06-29  12902 2015-06-29 00:00:02 2015-06-29 23:59:54  0.002500
# 2015-06-30  12855 2015-06-30 00:00:01 2015-06-30 23:59:55  0.048333
# 2015-07-01  12503 2015-07-01 00:00:02 2015-07-01 23:59:55  0.004722
# 2015-07-02  11948 2015-07-02 00:00:01 2015-07-02 23:59:54  1.750833
# 2015-07-03  12831 2015-07-03 00:00:01 2015-07-03 23:59:54  0.002500
# 2015-07-04  12883 2015-07-04 00:00:01 2015-07-04 23:59:59  0.002500
# 2015-07-05  12876 2015-07-05 00:00:06 2015-07-05 23:59:59  0.002500
# 2015-07-06  12901 2015-07-06 00:00:06 2015-07-06 23:59:55  0.003889
# 2015-07-07  12824 2015-07-07 00:00:01 2015-07-07 23:59:53  0.043889
# 2015-07-08  12584 2015-07-08 00:00:00 2015-07-08 23:59:53  0.627222
# 2015-07-09  12694 2015-07-09 00:00:00 2015-07-09 23:59:54  0.335278
# 2015-07-10   6422 2015-07-10 00:00:00 2015-07-10 11:56:35  0.003056
#
#            EnergySumOfParts PctAccountedEnergy Issues            \
#                         sum                std    sum      mean
# Time
# 2013-10-09         0.638810       2.646825e-01    6.0  0.001162
# 2013-10-10         2.677231       7.198488e-01    6.0  0.000466
# 2013-10-11         1.358534       2.392613e-01    6.0  0.000440
# 2013-10-12         1.303619       2.482368e-01    6.0  0.000432
# 2013-10-13         1.272069       2.108695e-01    6.0  0.000420
# 2013-10-14         1.264994       2.402216e-01    6.0  0.000423
# 2013-10-15         1.175899       2.428015e-01    6.0  0.000426
# 2013-10-16         1.181208       2.290207e-01    6.0  0.000429
# 2013-10-17         1.216740       2.108927e-01    6.0  0.000424
# 2013-10-18         1.249720       3.087982e-01    6.0  0.000428
# 2013-10-19         1.223012       2.257891e-01    6.0  0.000423
# 2013-10-20         1.255933       2.497744e-01    6.0  0.000423
# 2013-10-21         1.232078       2.368220e-01    6.0  0.000438
# 2013-10-22         1.447458       2.345008e-01    6.0  0.000426
# 2013-10-23         3.040557       5.882639e-01    6.0  0.000437
# 2013-10-24         2.376813       5.351989e-01    6.0  0.000433
# 2013-10-25         2.736741       3.562355e-01    6.0  0.000428
# 2013-10-26         1.970331       2.422977e-01    6.0  0.000437
# 2013-10-27         2.907925       3.878716e-01    6.0  0.000413
# 2013-10-28         2.070765       2.994377e-01    6.0  0.000436
# 2013-10-29         3.166920       4.298412e-01    6.0  0.000431
# 2013-10-30         1.989631       3.206121e-01    6.0  0.000441
# 2013-10-31         2.780889       3.354356e-01    6.0  0.000437
# 2013-11-01         1.828881       2.596515e-01    6.0  0.000426
# 2013-11-02         1.881561       2.417096e-01    6.0  0.000421
# 2013-11-03         3.108163       3.022331e-01    6.0  0.000428
# 2013-11-04         1.779923       2.806290e-01    6.0  0.000427
# 2013-11-05         1.580562       2.076540e-01    6.0  0.000450
# 2013-11-06         2.483395       2.831662e-01    6.0  0.000567
# 2013-11-07         0.965210       3.293140e-01    6.0  0.001511
# ...                     ...                ...    ...       ...
# 2015-06-11              NaN                NaN    NaN       NaN
# 2015-06-12              NaN                NaN    NaN       NaN
# 2015-06-13              NaN                NaN    NaN       NaN
# 2015-06-14              NaN                NaN    NaN       NaN
# 2015-06-15              NaN                NaN    NaN       NaN
# 2015-06-16              NaN                NaN    NaN       NaN
# 2015-06-17              NaN                NaN    NaN       NaN
# 2015-06-18         4.914494       1.123247e-03    6.0  0.000501
# 2015-06-19         5.279756       2.444121e-19    6.0  0.000465
# 2015-06-20         5.280061       2.120044e-19    6.0  0.000467
# 2015-06-21         5.280061       0.000000e+00    6.0  0.000468
# 2015-06-22         5.279878       2.996098e-19    6.0  0.000466
# 2015-06-23         1.944250       5.371775e-19    6.0  0.001284
# 2015-06-24         2.553571       4.689844e-04    6.0  0.000970
# 2015-06-25         5.280000       4.411850e-19    6.0  0.000466
# 2015-06-26         5.279572       0.000000e+00    6.0  0.000466
# 2015-06-27         5.280122       3.668316e-19    6.0  0.000466
# 2015-06-28         5.279878       3.018694e-19    6.0  0.000473
# 2015-06-29         5.279878       2.443647e-19    6.0  0.000465
# 2015-06-30         5.280000       2.448111e-19    6.0  0.000467
# 2015-07-01         5.279939       4.437066e-18    6.0  0.000480
# 2015-07-02         5.279939       2.199133e-19    6.0  0.000502
# 2015-07-03         5.279939       2.450400e-19    6.0  0.000468
# 2015-07-04         5.280244       2.445449e-19    6.0  0.000466
# 2015-07-05         5.279939       3.459327e-19    6.0  0.000466
# 2015-07-06         5.279694       1.221871e-19    6.0  0.000465
# 2015-07-07         5.279878       2.740378e-19    6.0  0.000468
# 2015-07-08         5.279939       0.000000e+00    6.0  0.000477
# 2015-07-09         5.280000       0.000000e+00    6.0  0.000473
# 2015-07-10         2.627839       1.731884e-19    6.0  0.000934
#
#            EnergyAppliance0 EnergyAppliance1  ...   EnergyAppliance5  \
#                         sum              sum  ...                sum
# Time                                          ...
# 2013-10-09         5.156559         0.132198  ...           0.000000
# 2013-10-10        13.737292         0.415929  ...           0.000000
# 2013-10-11         5.657950         0.319277  ...           0.000000
# 2013-10-12         5.147623         0.318191  ...           0.000000
# 2013-10-13         5.143264         0.276128  ...           0.000000
# 2013-10-14         5.899516         0.260000  ...           0.000000
# 2013-10-15         7.707154         0.249149  ...           0.000000
# 2013-10-16         6.023909         0.251429  ...           0.000000
# 2013-10-17        11.049612         0.246270  ...           0.000000
# 2013-10-18         5.212062         0.287654  ...           0.000000
# 2013-10-19         4.443903         0.278020  ...           0.000000
# 2013-10-20         7.934409         0.276765  ...           0.000000
# 2013-10-21         5.113026         0.273972  ...           0.000000
# 2013-10-22         8.274716         0.316513  ...           0.000005
# 2013-10-23        14.176599         0.445539  ...           1.091535
# 2013-10-24        14.463463         0.423938  ...           0.264950
# 2013-10-25        11.192323         0.452310  ...           0.000000
# 2013-10-26         9.573078         0.381678  ...           0.287262
# 2013-10-27        13.275011         0.433610  ...           0.532796
# 2013-10-28        11.856033         0.418273  ...           0.270079
# 2013-10-29        16.575772         0.402902  ...           0.654803
# 2013-10-30        16.624978         0.416539  ...           0.332917
# 2013-10-31        12.142193         0.437403  ...           0.281664
# 2013-11-01         9.192136         0.423919  ...           0.000000
# 2013-11-02         9.973180         0.360706  ...           0.290569
# 2013-11-03        15.575221         0.400877  ...           0.283126
# 2013-11-04        14.877280         0.359731  ...           0.298841
# 2013-11-05        11.176480         0.362711  ...           0.000000
# 2013-11-06         9.872443         0.360229  ...           0.000000
# 2013-11-07         3.475339         0.157750  ...           0.321963
# ...                     ...              ...  ...                ...
# 2015-06-11              NaN              NaN  ...                NaN
# 2015-06-12              NaN              NaN  ...                NaN
# 2015-06-13              NaN              NaN  ...                NaN
# 2015-06-14              NaN              NaN  ...                NaN
# 2015-06-15              NaN              NaN  ...                NaN
# 2015-06-16              NaN              NaN  ...                NaN
# 2015-06-17              NaN              NaN  ...                NaN
# 2015-06-18        39.964272         2.077491  ...           0.000000
# 2015-06-19        42.934012         2.231897  ...           0.000000
# 2015-06-20        42.936497         2.232026  ...           0.000000
# 2015-06-21        42.936497         2.232026  ...           0.000000
# 2015-06-22        42.935006         2.231948  ...           0.000000
# 2015-06-23        15.810288         0.821887  ...           0.000000
# 2015-06-24        20.765321         1.079472  ...           0.000000
# 2015-06-25        42.936000         2.232000  ...           0.000000
# 2015-06-26        42.932521         2.231819  ...           0.000000
# 2015-06-27        42.936994         2.232052  ...           0.000000
# 2015-06-28        42.935006         2.231948  ...           0.000000
# 2015-06-29        42.935006         2.231948  ...           0.000000
# 2015-06-30        42.936000         2.232000  ...           0.000000
# 2015-07-01        42.935503         2.231974  ...           0.000000
# 2015-07-02        42.935503         2.231974  ...           0.000000
# 2015-07-03        42.935503         2.231974  ...           0.000000
# 2015-07-04        42.937988         2.232103  ...           0.000000
# 2015-07-05        42.935503         2.231974  ...           0.000000
# 2015-07-06        42.933515         2.231871  ...           0.000000
# 2015-07-07        42.935006         2.231948  ...           0.000000
# 2015-07-08        42.935503         2.231974  ...           0.000000
# 2015-07-09        42.936000         2.232000  ...           0.000000
# 2015-07-10        21.369108         1.110859  ...           0.000000
#
#            EnergyAppliance6 EnergyAppliance7 EnergyAppliance8  \
#                         sum              sum              sum
# Time
# 2013-10-09         0.000000         0.000000         0.075760
# 2013-10-10         0.882526         0.028912         0.163212
# 2013-10-11         0.000000         0.000000         0.001484
# 2013-10-12         0.000000         0.000000         0.001527
# 2013-10-13         0.000000         0.000000         0.001493
# 2013-10-14         0.000000         0.000000         0.001496
# 2013-10-15         0.000004         0.000000         0.001545
# 2013-10-16         0.000000         0.000000         0.001496
# 2013-10-17         0.000000         0.000000         0.001525
# 2013-10-18         0.000000         0.000000         0.001482
# 2013-10-19         0.000000         0.000000         0.001497
# 2013-10-20         0.000000         0.000000         0.001512
# 2013-10-21         0.000000         0.000000         0.001494
# 2013-10-22         0.000000         0.037400         0.075208
# 2013-10-23         0.000071         0.043652         0.214368
# 2013-10-24         0.000000         0.013100         0.100533
# 2013-10-25         0.892805         0.032268         0.224427
# 2013-10-26         0.000089         0.011090         0.144156
# 2013-10-27         0.000000         0.125704         0.255118
# 2013-10-28         0.000000         0.068112         0.123162
# 2013-10-29         0.936863         0.013203         0.083543
# 2013-10-30         0.000000         0.000000         0.132782
# 2013-10-31         0.894181         0.054892         0.081291
# 2013-11-01         0.000000         0.013653         0.090911
# 2013-11-02         0.000000         0.052972         0.138959
# 2013-11-03         0.925270         0.079268         0.235026
# 2013-11-04         0.000000         0.049911         0.136753
# 2013-11-05         0.000000         0.041604         0.253891
# 2013-11-06         0.930889         0.016665         0.186051
# 2013-11-07         0.000000         0.000000         0.001407
# ...                     ...              ...              ...
# 2015-06-11              NaN              NaN              NaN
# 2015-06-12              NaN              NaN              NaN
# 2015-06-13              NaN              NaN              NaN
# 2015-06-14              NaN              NaN              NaN
# 2015-06-15              NaN              NaN              NaN
# 2015-06-16              NaN              NaN              NaN
# 2015-06-17              NaN              NaN              NaN
# 2015-06-18         0.000000         0.000000         0.446772
# 2015-06-19         0.000000         0.000000         0.479978
# 2015-06-20         0.000000         0.000000         0.480006
# 2015-06-21         0.000000         0.000000         0.480006
# 2015-06-22         0.000000         0.000000         0.479989
# 2015-06-23         0.000000         0.000000         0.176750
# 2015-06-24         0.000000         0.000000         0.232139
# 2015-06-25         0.000000         0.000000         0.480000
# 2015-06-26         0.000000         0.000000         0.479961
# 2015-06-27         0.000000         0.000000         0.480011
# 2015-06-28         0.000000         0.000000         0.479989
# 2015-06-29         0.000000         0.000000         0.479989
# 2015-06-30         0.000000         0.000000         0.480000
# 2015-07-01         0.000000         0.000000         0.479994
# 2015-07-02         0.000000         0.000000         0.479994
# 2015-07-03         0.000000         0.000000         0.479994
# 2015-07-04         0.000000         0.000000         0.480022
# 2015-07-05         0.000000         0.000000         0.479994
# 2015-07-06         0.000000         0.000000         0.479972
# 2015-07-07         0.000000         0.000000         0.479989
# 2015-07-08         0.000000         0.000000         0.479994
# 2015-07-09         0.000000         0.000000         0.480000
# 2015-07-10         0.000000         0.000000         0.238894
#
#            EnergyAppliance9 SumToMainCorr PctAccountedEnergy  HourRange House  \
#                         sum                            total
# Time
# 2013-10-09         0.010896      0.370633           0.123883  10.895000     1
# 2013-10-10         0.023990      0.255051           0.194888  23.996111     1
# 2013-10-11         0.023997      0.396753           0.240111  23.996111     1
# 2013-10-12         0.023970      0.831595           0.253247  23.999444     1
# 2013-10-13         0.023989      0.549391           0.247327  23.999444     1
# 2013-10-14         0.023982      0.283215           0.214423  23.998889     1
# 2013-10-15         0.023990      0.732816           0.152572  23.999444     1
# 2013-10-16         0.024001      0.334634           0.196087  23.999444     1
# 2013-10-17         0.023982      0.351374           0.110116  23.996111     1
# 2013-10-18         0.024001      0.641928           0.239775  23.999722     1
# 2013-10-19         0.023985      0.494017           0.275211  23.999444     1
# 2013-10-20         0.023958      0.295027           0.158289  23.999444     1
# 2013-10-21         0.023981      0.557985           0.240968  23.999167     1
# 2013-10-22         0.023980      0.667717           0.174925  23.999444     1
# 2013-10-23         0.024001      0.148118           0.214477  23.999444     1
# 2013-10-24         0.023988      0.369739           0.164332  23.999444     1
# 2013-10-25         0.023981      0.374770           0.244519  23.999444     1
# 2013-10-26         0.022988      0.278063           0.205820  22.999167     1
# 2013-10-27         0.023992      0.406501           0.219053  23.999444     1
# 2013-10-28         0.024001      0.615821           0.174659  23.999444     1
# 2013-10-29         0.023998      0.447428           0.191057  23.999444     1
# 2013-10-30         0.023993      0.513301           0.119677  23.999167     1
# 2013-10-31         0.023987      0.538926           0.229027  23.999444     1
# 2013-11-01         0.024001      0.546201           0.198961  23.999167     1
# 2013-11-02         0.023984      0.356273           0.188662  23.999167     1
# 2013-11-03         0.023980      0.335051           0.199558  23.999444     1
# 2013-11-04         0.023990      0.201261           0.119640  23.999444     1
# 2013-11-05         0.023991      0.441701           0.141419  23.999444     1
# 2013-11-06         0.023977      0.579260           0.251548  23.996667     1
# 2013-11-07         0.010052      0.352267           0.277731  10.054167     1
# ...                     ...           ...                ...        ...   ...
# 2015-06-11              NaN           NaN                NaN        NaN    21
# 2015-06-12              NaN           NaN                NaN        NaN    21
# 2015-06-13              NaN           NaN                NaN        NaN    21
# 2015-06-14              NaN           NaN                NaN        NaN    21
# 2015-06-15              NaN           NaN                NaN        NaN    21
# 2015-06-16              NaN           NaN                NaN        NaN    21
# 2015-06-17              NaN           NaN                NaN        NaN    21
# 2015-06-18         1.027576      0.999879           0.122972  22.337222    21
# 2015-06-19         1.103949      1.000000           0.122974  23.997222    21
# 2015-06-20         1.104013      1.000000           0.122974  23.998611    21
# 2015-06-21         1.104013      1.000000           0.122974  23.998611    21
# 2015-06-22         1.103974      1.000000           0.122974  23.997778    21
# 2015-06-23         0.406525      1.000000           0.122974   8.835833    21
# 2015-06-24         0.533919      0.999999           0.122973  11.605556    21
# 2015-06-25         1.104000      1.000000           0.122974  23.998333    21
# 2015-06-26         1.103911      1.000000           0.122974  23.996389    21
# 2015-06-27         1.104026      1.000000           0.122974  23.998889    21
# 2015-06-28         1.103974      1.000000           0.122974  23.997778    21
# 2015-06-29         1.103974      1.000000           0.122974  23.997778    21
# 2015-06-30         1.104000      1.000000           0.122974  23.998333    21
# 2015-07-01         1.103987      1.000000           0.122974  23.998056    21
# 2015-07-02         1.103987      1.000000           0.122974  23.998056    21
# 2015-07-03         1.103987      1.000000           0.122974  23.998056    21
# 2015-07-04         1.104051      1.000000           0.122974  23.999444    21
# 2015-07-05         1.103987      1.000000           0.122974  23.998056    21
# 2015-07-06         1.103936      1.000000           0.122974  23.996944    21
# 2015-07-07         1.103974      1.000000           0.122974  23.997778    21
# 2015-07-08         1.103987      1.000000           0.122974  23.998056    21
# 2015-07-09         1.104000      1.000000           0.122974  23.998333    21
# 2015-07-10         0.549457      1.000000           0.122974  11.943056    21
#
#            Delete
#
# Time
# 2013-10-09      1
# 2013-10-10      0
# 2013-10-11      0
# 2013-10-12      0
# 2013-10-13      0
# 2013-10-14      0
# 2013-10-15      0
# 2013-10-16      0
# 2013-10-17      0
# 2013-10-18      0
# 2013-10-19      0
# 2013-10-20      0
# 2013-10-21      1
# 2013-10-22      0
# 2013-10-23      0
# 2013-10-24      0
# 2013-10-25      0
# 2013-10-26      1
# 2013-10-27      0
# 2013-10-28      1
# 2013-10-29      0
# 2013-10-30      0
# 2013-10-31      0
# 2013-11-01      0
# 2013-11-02      0
# 2013-11-03      0
# 2013-11-04      0
# 2013-11-05      0
# 2013-11-06      0
# 2013-11-07      1
# ...           ...
# 2015-06-11      1
# 2015-06-12      1
# 2015-06-13      1
# 2015-06-14      1
# 2015-06-15      1
# 2015-06-16      1
# 2015-06-17      1
# 2015-06-18      1
# 2015-06-19      0
# 2015-06-20      0
# 2015-06-21      0
# 2015-06-22      0
# 2015-06-23      1
# 2015-06-24      1
# 2015-06-25      0
# 2015-06-26      0
# 2015-06-27      0
# 2015-06-28      0
# 2015-06-29      0
# 2015-06-30      0
# 2015-07-01      0
# 2015-07-02      1
# 2015-07-03      0
# 2015-07-04      0
# 2015-07-05      0
# 2015-07-06      0
# 2015-07-07      0
# 2015-07-08      1
# 2015-07-09      1
# 2015-07-10      1
#
# [10900 rows x 23 columns]

# %%
# %run create_data

def plot_samples(condition, n=10):
    sample = dstats.loc[condition].sample(n)
    dt_series = sample.index.to_datetime()
    house_ids = sample['House'].values
    for dt, house_id in zip(dt_series, house_ids):
        plot_day(dt=dt, house_id=house_id)
        plt.show()

np.random.seed(1)
# print 'UnixDiff'
# plot_samples(dstats[('UnixDiff', 'max')] > 0.25, 10)
# print 'HourRange'
# plot_samples(dstats['HourRange'] < 23.5, 10)
print 'RowNum'
plot_samples((np.isfinite(dstats[('RowNum', 'len')].values)) & (dstats[('RowNum', 'len')] < 2000), 10)
# print 'PctAccountedEnergy - identity'
# plot_samples(dstats[('PctAccountedEnergy', 'identity')] > float('inf'), 10)
# print 'PctAccountedEnergy - std'
# plot_samples(dstats[('PctAccountedEnergy', 'std')] > float('inf'), 10)
# print 'SumToMainCorr'
# plot_samples(dstats['SumToMainCorr'] < 0.20, 10)
# print 'Issues'
# plot_samples(dstats[('Issues', 'mean')] > 0.01, 10)

# %%
# house_id = 16
# dt = datetime(2014,10,11)
# df = get_df(house_id=house_id, dt_start=dt)

# %%
# dstats.to_csv(os.path.join(dir_data, 'dstats_TEMP.csv'))

# %%
dstats = clean_daily_stats(dstats)
# Out:
# cleaning daily stats...
# Condition 1: 1013 (9.3%) rows affected in total, 1013 (9.3%) new
# Condition 2: 750 (6.9%) rows affected in total, 650 (6%) new
# Condition 3: 605 (5.6%) rows affected in total, 422 (3.9%) new
# Condition 4: 6 (0.055%) rows affected in total, 0 (0%) new
# Condition 5: 64 (0.59%) rows affected in total, 21 (0.19%) new
# Condition 6: 1524 (14%) rows affected in total, 1234 (11%) new
# Condition 7: 1 (0.0092%) rows affected in total, 1 (0.0092%) new
# Total rows marked for deletion: 3341 (31%)

# %%
# %run create_data

get_app_nums(4, 'fridge')
# get_energy(dstats, 4, datetime.datetime(2013,10,12), [1, 3])
# Out:
# [1, 3]

# %%
# get_house_app_tuples('washing machine', True)

# %%
# agg.loc[agg['House']==house_id].loc[str(dt.date())]['Delete'].values[0]

# %%
X, Y, x_house, x_date = create_data([8], app_names, dstats, dir_data)
# Out:
# Creating data for house 8...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-597-41b22ccf0b53> in <module>()
#      70
#      71
# ---> 72 X, Y, x_house, x_date = create_X_Y_data([8], app_names, dir_data)
#
# <ipython-input-597-41b22ccf0b53> in create_X_Y_data(house_ids, app_names, dir_data, desired_sample_rate, is_debug)
#      27
#      28             # Check if we want to process this data.
# ---> 29             data_okay = dstats.loc[dstats['House']==house_id].loc[str(dt_start.date())]['Delete'].values[0] == 0
#      30             if not data_okay:
#      31                 continue
#
# /Users/sipola/miniconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /Users/sipola/miniconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1480
#    1481         # fall thru to straight lookup
# -> 1482         self._has_valid_type(key, axis)
#    1483         return self._get_label(key, axis=axis)
#    1484
#
# /Users/sipola/miniconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1417                 raise
#    1418             except:
# -> 1419                 error()
#    1420
#    1421         return True
#
# /Users/sipola/miniconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in error()
#    1404                                     "key")
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#    1408             try:
#
# KeyError: 'the label [2015-05-11] is not in the [index]'

# %%
tmp = np.array(datetime(2014,5,10).date())
# print tmp.size
# dstats.loc['2014-05-11']
dstats.loc[dstats['House']==8].loc[str(dt_start.date())]
# Out:
# RowNum              len                     1061
# Time                min      2013-11-01 22:13:18
#                     max      2013-11-01 23:59:57
# UnixDiff            max               0.00416667
# EnergySumOfParts    sum                 0.169491
# PctAccountedEnergy  std                 0.241916
# Issues              sum                        6
#                     mean              0.00565504
# EnergyAppliance0    sum                 0.435874
# EnergyAppliance1    sum                0.0419114
# EnergyAppliance2    sum                0.0350314
# EnergyAppliance3    sum                        0
# EnergyAppliance4    sum               0.00323583
# EnergyAppliance5    sum                        0
# EnergyAppliance6    sum                0.0306517
# EnergyAppliance7    sum                0.0552897
# EnergyAppliance8    sum               0.00337139
# EnergyAppliance9    sum                        0
# SumToMainCorr                           0.811589
# PctAccountedEnergy  total               0.388854
# HourRange                                 1.7775
# House                                          8
# Name: 2013-11-01 00:00:00, dtype: object

# %%
X = np.load(os.path.join(dir_data, 'X.npy'))
Y = np.load(os.path.join(dir_data, 'Y.npy'))
x_house = np.load(os.path.join(dir_data, 'x_house.npy'))
x_date = np.load(os.path.join(dir_data, 'x_date.npy'))

house_ids_plot = list(set(x_house))
for i, app_name in enumerate(app_names):
    y = pd.DataFrame({'Energy': [y_row[i] for y_row in Y],
                      'House': x_house})
    y = y[y['Energy'] < np.percentile(y['Energy'], 99)]
    for house_id_plot in house_ids_plot:
        y_house = y.loc[y['House'] == house_id_plot]
        # ax = sns.kdeplot(y_house['Energy'].values, label='House {}'.format(house_id_plot))
        ax = sns.kdeplot(y_house['Energy'].values, color='darkgray')
        ax.set_title('Density of daily energy used by {} (by home)'.format(app_name))
        ax.set_xlabel('Energy (kWh) per day')
    plt.show()

# %%
y = pd.DataFrame({'Energy': dstats[('EnergyAppliance0', 'sum')],
                  'House': dstats['House']})
# y = y[y['Energy'] < np.percentile(y['Energy'], 95)]
# print y
not_too_big   = y['Energy'] < np.percentile(y['Energy'].dropna(), 99.99)
not_too_small = y['Energy'] > np.percentile(y['Energy'].dropna(), 0.01)
y = y[(not_too_big) & (not_too_small)]
for house_id in house_ids:
    y_house = y.loc[y['House'] == house_id]
    ax = sns.kdeplot(y_house['Energy'].values, color='darkgray')
    ax.set_title('Density of total daily energy (by home)')
    ax.set_xlabel('Energy (kWh) per day')
plt.show()

# %%
# One day with negative aggregate.
plot_day(3, datetime(2014,4,6))

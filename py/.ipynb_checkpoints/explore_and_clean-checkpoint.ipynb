# %% [markdown]
# TODO:
# - Make code that plots total energy hist for day for each appliance
# - Show histogram of energy used in each home.
# - Show histogram of energy used by appliances in each home.
# - Replicate table 3.4 from Chaoyun's paper
# - Solar panels
# - Mystery kettle
# - House 12 has kettle mistake (says 6 when it should be 4). See
# - Check Chaoyun's code

# %%
import os
import re
import pandas as pd
import numpy as np
from collections import OrderedDict
from __future__ import division
import time
from datetime import datetime
from datetime import date
from datetime import timedelta
from dateutil.parser import parse

# import sqlite3

from ggplot import *
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

from utils import *
from create_data import *
from get_activations import *

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# ### R stuff

# %%
# If you want to ignore R warnings.
# import warnings
# warnings.filterwarnings('ignore')

# from rpy2.robjects.packages import isinstalled
# from rpy2.robjects.vectors import StrVector
# import rpy2.robjects.packages as rpackages
# from rpy2.robjects.packages import importr

# utils = rpackages.importr('utils')
# utils.chooseCRANmirror(ind=1) # select the first mirror in the list

# packnames = ('forecast')
# utils.install_packages(packnames)

# isinstalled('forecast')

# %%R
# y <- 1

# %load_ext rpy2.ipython

# %% [markdown]
# ### Define project vars

# %%
dir_proj = '/Users/sipola/Google Drive/education/coursework/graduate/edinburgh/dissertation/thesis'
dir_data = os.path.join(dir_proj, 'data')
dir_run = os.path.join(dir_proj, 'run', str(date.today()))

# %%
house_ids = range(1, 22)
house_ids.remove(14)  # no house 14
app_names = ['fridge', 'kettle', 'washing machine', 'dishwasher', 'microwave']
# tz = 'Europe/London'

# %%
# params_appliance = get_params_appliance()
dir_refit_csv = os.path.join(dir_data, 'CLEAN_REFIT_081116')
dir_refit = os.path.join(dir_data, 'refit')

# %%
save_refit_data(dir_refit_csv=dir_refit_csv,
                dir_refit_np=dir_refit,
                nrows=None)
# Out:
# writing REFIT data...
# added house 1 (0.31 min)
# added house 2 (0.25 min)
# added house 3 (0.32 min)
# added house 4 (0.37 min)
# added house 5 (0.37 min)
# added house 6 (0.31 min)
# added house 7 (0.32 min)
# added house 8 (0.33 min)
# added house 9 (0.24 min)
# added house 10 (0.34 min)
# added house 11 (0.32 min)
# added house 12 (0.29 min)
# added house 13 (0.26 min)
# added house 15 (0.36 min)
# added house 16 (0.27 min)
# added house 17 (0.25 min)
# added house 18 (0.24 min)
# added house 19 (0.22 min)
# added house 20 (0.19 min)
# added house 21 (0.2 min)
# done!

# %%
apps = pd.read_csv(os.path.join(dir_data, 'appliances.csv'))
app_dict = OrderedDict([
    ('fridge', {'col': 'Fridge', 'pattern': 'fridge'}),
    ('kettle', {'col': 'Kettle', 'pattern': 'kettle$'}),  # pattern ignores 'Kettle/Toaster'
    ('washing machine', {'col': 'WashingMachine', 'pattern': 'washing *machine'}),
    ('dishwasher', {'col': 'DishWasher', 'pattern': 'dish *washer'}),
    ('microwave', {'col': 'Microwave', 'pattern': '^microwave'})  # pattern ignores 'Combination Microwave'
])

apps = apps_add_cols_from_patterns(app_dict)

# %%
get_house_app_tuples, get_app_nums, get_app_name = create_app_funs(apps, app_dict)
load_app, load_ts, load_issues = create_load_funs(dir_refit)

# app_col, pattern = app_col_and_pattern_tuples[1]
# for i in apps.loc[apps[app_col] == 1]['ApplianceOrig'].values:
#     print i

# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('fridge')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('kettle')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('washi')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('dish')]
# apps.loc[apps['ApplianceOrig'].str.lower().str.contains('micro')]

# get_house_app_tuples('fridge')
# get_house_app_tuples('kettle')
# get_house_app_tuples('washing machine')

# %%
create_daily_plots(house_ids, dir_run)

# %%
create_daily_stats(house_ids,
                   pkl_path=os.path.join(dir_data, 'stats_by_day.pkl'),
                   nrow=None)
# Out:
# calculating stats for house 1...
# calculating stats for house 2...

# %%
stats = pd.read_pickle(os.path.join(dir_data, 'stats_by_day.pkl'))

# %%
# plot_day(2, datetime.datetime(2014,9,7), figsize=(11,8))

# %%
vars_to_plot = [{'col': ('UnixDiff', 'max'), 'ylab': 'Hours', 'title': 'Max difference in timestamps'},
                {'col': 'HourRange', 'ylab': 'Hours', 'title': 'Timestamp range'},
                {'col': ('RowNum', 'len'), 'ylab': 'Count', 'title': 'Number of observations'},
                {'col': ('PctAccountedEnergy', 'total'), 'ylab': 'Proportion of energy', 'title': 'Proportion of energy accounted for by appliances'},
                {'col': ('PctAccountedEnergy', 'std'), 'ylab': 'Proportion of energy', 'title': 'Proportion of energy accounted for by appliances (std)'},
                {'col': 'SumToMainCorr', 'ylab': 'Correlation', 'title': 'Correlation between sum of appliances and main'}]
for var_to_plot in vars_to_plot:
    var_name = var_to_plot['col']
    if isinstance(var_name, tuple):
        var_name = '_'.join(var_name)
    plot_data = pd.DataFrame({var_name: sorted(stats[var_to_plot['col']].dropna())})
    plot_data['Proportion'] = [i/plot_data.shape[0] for i in range(plot_data.shape[0])]
    ax = plot_data.set_index('Proportion').plot()
    ax.set_title(var_to_plot['title'])
    ax.set_ylabel(var_to_plot['ylab'])
    ax.legend().set_visible(False)

# %%
for var_to_plot in vars_to_plot:
    var_name = var_to_plot['col']
    if isinstance(var_name, tuple):
        var_name = '_'.join(var_name)
    # print agg[var_to_plot['col']].dropna()
    kde_data = stats[var_to_plot['col']].replace([np.inf, -np.inf], np.nan).dropna().values
    ax = sns.distplot(kde_data, rug=False)
    ax.set_title(var_to_plot['title'])
    ax.set_xlabel(var_to_plot['ylab'])
    plt.show()

# %%
def plot_samples(condition, n=10):
    sample = agg.loc[condition].sample(n)
    ts_series = sample.index.to_datetime()
    house_ids = sample['House'].values
    for ts, house_id in zip(ts_series, house_ids):
        dt = datetime.datetime(ts.year, ts.month, ts.day)
        plot_day(dt=dt, house_id=house_id)
        plt.show()

np.random.seed(1)
print 'TimestampDiff'
plot_samples(agg[('TimestampDiff', 'max')] > 0.25, 10)
# print 'HourRange'
# plot_samples(agg['HourRange'] < 23.5, 10)
# print 'RowNum'
# plot_samples(agg[('RowNum', 'len')] < 250, 10)
# print 'PctAccountedEnergy - identity'
# plot_samples(agg[('PctAccountedEnergy', 'identity')] > float('inf'), 10)
# print 'PctAccountedEnergy - std'
# plot_samples(agg[('PctAccountedEnergy', 'std')] > float('inf'), 10)
# print 'SumToMainCorr'
# plot_samples(agg['SumToMainCorr'] < 0.25, 10)
# Out:
# TimestampDiff

# %%
# house_id = 8
# dt = datetime.datetime(2014,1,5)
# app = 'appliance5'
# vals = get_df(house_id=house_id, dt_start=dt)[app].values

# %%
# idx = np.where(vals > 8000)[0]
# idx_more = []
# for i in range(-10, 10):
#     idx_more.extend([j+i for j in idx])
# get_df(house_id=house_id, dt_start=dt)[app].iloc[idx_more]

# %%
conds = [
    agg[('TimestampDiff', 'max')] > 0.25,  # 15 min
    agg['HourRange'] < 23.5,
    agg[('RowNum', 'len')] < 250,
    agg[('PctAccountedEnergy', 'identity')] > float('inf'),
    agg[('PctAccountedEnergy', 'std')] > float('inf'),
    agg['SumToMainCorr'] < 0.25
]
total_rows = agg.shape[0]
delete = pd.DataFrame({'Timestamp': agg.index,
                       'Delete': np.zeros(total_rows, dtype=int)})
delete.set_index('Timestamp', inplace=True)
for cond_num, cond in enumerate(conds):
    array = cond.as_matrix()
    rows_affected = sum(array)
    new_rows_deleted = sum([i == 0 and j == 1 for i, j in zip(delete['Delete'].values, array)])
    delete.loc[array] = 1
    print 'Condition {}: {} ({:0.2g}%) rows affected in total, {} ({:0.2g}%) new'.format(
        cond_num+1,
        rows_affected,
        rows_affected / total_rows * 100,
        new_rows_deleted,
        new_rows_deleted / total_rows * 100
    )
rows_deleted = sum(delete['Delete'].values)
print '=====\nTotal rows deleted: {} ({:0.2g}%)'.format(rows_deleted, rows_deleted / total_rows * 100)
# Out:
# Condition 1: 596 (5.5%) rows affected in total, 596 (5.5%) new
# Condition 2: 623 (5.7%) rows affected in total, 447 (4.1%) new
# Condition 3: 920 (8.4%) rows affected in total, 909 (8.3%) new
# Condition 4: 0 (0%) rows affected in total, 0 (0%) new
# Condition 5: 0 (0%) rows affected in total, 0 (0%) new
# Condition 6: 866 (7.9%) rows affected in total, 794 (7.3%) new
# =====
# Total rows deleted: 2746 (25%)

# %%
agg['Delete'] = delete['Delete']

# %%
# agg = agg.loc[agg['Delete'] == 0]

# %%
agg.loc[agg['House'] == 1]['EnergyAppliance5']
# Out:
#                   sum
# Timestamp
# 2013-10-09        0.0
# 2013-10-10        0.0
# 2013-10-11        0.0
# 2013-10-12        0.0
# 2013-10-13        0.0
# 2013-10-14        0.0
# 2013-10-15        0.0
# 2013-10-16        0.0
# 2013-10-17        0.0
# 2013-10-18        0.0
# 2013-10-19        0.0
# 2013-10-20        0.0
# 2013-10-21        0.0
# 2013-10-22       19.0
# 2013-10-23  3936435.0
# 2013-10-24   952176.0
# 2013-10-25        0.0
# 2013-10-26  1036993.0
# 2013-10-27  1921829.0
# 2013-10-28   976482.0
# 2013-10-29  2369578.0
# 2013-10-30  1198765.0
# 2013-10-31  1013926.0
# 2013-11-01        0.0
# 2013-11-02  1045684.0
# 2013-11-03  1021327.0
# 2013-11-04  1078925.0
# 2013-11-05        0.0
# 2013-11-06        0.0
# 2013-11-07  1162370.0
# ...               ...
# 2015-06-11        NaN
# 2015-06-12        NaN
# 2015-06-13        NaN
# 2015-06-14        NaN
# 2015-06-15        NaN
# 2015-06-16        NaN
# 2015-06-17        NaN
# 2015-06-18    10752.0
# 2015-06-19        0.0
# ...

# %%
get_house_app_tuples('fridge')
# Out:
# [(1, 1),
#  (2, 1),
#  (3, 2),
#  (4, 1),
#  (4, 3),
#  (5, 1),
#  (7, 1),
#  (8, 1),
#  (9, 1),
#  (10, 4),
#  (11, 1),
#  (11, 2),
#  (12, 1),
#  (15, 1),
#  (16, 1),
#  (16, 2),
#  (17, 2),
#  (18, 1),
#  (18, 3),
#  (19, 1),
#  (20, 1),
#  (21, 1)]

# %%
app_name2nums = OrderedDict()
app_name2nums['fridge'] = get_app_nums(4, 'fridge')

# %%
app_name2nums
# Out:
# OrderedDict([('fridge', [1, 3])])

# %%
def get_energy(house_id, dt, app_nums):
    '''
    When there are multiple cols for an appliance, it adds them.
    '''
    if not app_nums:
        # If home doesn't have this appliance, return zero energy.
        return 0.
    
    # Subset by house and appliance.
    cols = ['EnergyAppliance{}'.format(s) for s in app_nums]
    energy = agg.loc[(agg['House'] == house_id)][cols]
    
    # Subset by datetime.
    energy = energy.loc[str(dt.date())]
    
    return sum(energy.values)


# get_app_nums(4, 'fridge')
# get_energy(4, datetime.datetime(2013,10,12), [1, 3])

# %%
get_house_app_tuples('washing machine', True)
# Out:
#      House  ApplianceNum        ApplianceOrig        Appliance
# 4        1             5      Washing Machine  washing machine
# 10       2             2      Washing Machine  washing machine
# 23       3             6      Washing Machine  washing machine
# 30       4             4  Washing Machine (1)  washing machine
# 31       4             5  Washing Machine (2)  washing machine
# 38       5             3      Washing Machine  washing machine
# 46       6             2      Washing Machine  washing machine
# 58       7             5      Washing Machine  washing machine
# 66       8             4      Washing Machine  washing machine
# 74       9             3      Washing Machine  washing machine
# 85      10             5      Washing Machine  washing machine
# 92      11             3      Washing Machine  washing machine
# 110     13             3      Washing Machine  washing machine
# 119     15             3      Washing Machine  washing machine
# ...

# %%
agg.loc[agg['House']==house_id].loc[str(dt.date())]['Delete'].values[0]
# Out:
# 0

# %%
# Create data.

def create_data(house_ids, app_names, is_debug=True):
    
    X = []
    Y = []
    x_house = []
    x_date = []
    
    for house_id in house_ids:
        
        if is_debug:
            print 'Creating data for house {}...'.format(house_id)
            t0 = time.time()

        app_name2nums = OrderedDict()
        for app_name in app_names:
            app_name2nums[app_name] = get_app_nums(house_id, app_name)

        ts_series = load_ts(house_id)
        main = load_app(house_id, 0)

        dt_min = floor_time(ts2dt(int(ts_series.min())))
        dt_max = floor_time(ts2dt(int(ts_series.max())))

        all_dts = [dt_min + datetime.timedelta(days=d) for d in range(0, (dt_max-dt_min).days+1)]

        for dt_start in all_dts:

            # Check if we want to process this data.
            data_okay = agg.loc[agg['House']==house_id].loc[str(dt_start.date())]['Delete'].values[0] == 0
            if not data_okay:
                continue

            dt_end = dt_start + datetime.timedelta(days=1)
            # print dt_start
            # print dt_end
            ts_idx = get_ts_idx(ts_series=ts_series,
                                dt_start=dt_start)
            ts_day_actual = ts_series[ts_idx]
            ts_day_desired = range(dt2ts(dt_start) + 6, dt2ts(dt_end) + 6, 6)
            aligned_idx = align_arrays(ts_day_actual, ts_day_desired, padder=0)

            x = main[ts_idx][aligned_idx]
            y = []
            for app_name in app_names:
                y.append(get_energy(house_id, dt_start, app_name2nums[app_name]))

            X.append(x)
            x_house.append(house_id)
            x_date.append(dt_start.date())
            Y.append(y)

        if is_debug:
            t1 = time.time()
            print 'Created data for house {0} ({1:.2g} min)'.format(house_id, (t1 - t0)/60)
    
    return X, Y, x_house, x_date

# %%
app_names = ['fridge', 'kettle', 'washing machine']
X, Y, x_house, x_date = create_data(house_ids, app_names)
# Out:
# Creating data for house 1...
# Created data for house 1 (0.85 min)
# Creating data for house 2...
# Created data for house 2 (0.84 min)
# Creating data for house 3...
# Created data for house 3 (1.2 min)
# Creating data for house 4...
# Created data for house 4 (1.2 min)
# Creating data for house 5...
# Created data for house 5 (1.4 min)
# Creating data for house 6...
# Created data for house 6 (1 min)
# Creating data for house 7...
# Created data for house 7 (1.3 min)
# Creating data for house 8...
# Created data for house 8 (0.83 min)
# Creating data for house 9...
# Created data for house 9 (1.1 min)
# Creating data for house 10...
# Created data for house 10 (1.3 min)
# Creating data for house 11...
# Created data for house 11 (0.61 min)
# Creating data for house 12...
# Created data for house 12 (1 min)
# Creating data for house 13...
# Created data for house 13 (0.7 min)
# Creating data for house 15...
# Created data for house 15 (1.1 min)
# Creating data for house 16...
# ...

# %%
Y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-350-ed0bb6dc036e> in <module>()
# ----> 1 Y / 3.6e6
#
# TypeError: unsupported operand type(s) for /: 'list' and 'float'
